# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Decistion Tree

# %%
# Generate sample data
np.random.seed(123)
X = np.linspace(0, 6, 500)
noise = np.random.randn(500)
a, b = 2, 1
y = a*X + b + 0.5*(X+2)*noise

plt.plot(X, y, '.')
plt.show()

# %%
# # Split to train and tes

# test_indexes = np.random.randint(0, 499, 50)
# mask = np.ones(500).astype(int)
# mask[test_indexes] = 0

# X_train, X_test = X[mask], X[~mask]
# y_train, y_test = y[mask], y[~mask]

# plt.plot(X_train, y_train, '.')
# plt.plot(X_test, y_test, '.')
# plt.show()

# %%
lin_reg = LinearRegression()
lin_reg.fit(X, y.reshape(-1,1))

# %%
plt.plot(X, y, '.')
plt.plot(X, lin_reg.predict(y.reshape(-1,1)))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20732\1197489931.py in <module>
#       1 lin_reg = LinearRegression()
# ----> 2 lin_reg.fit(X, y.reshape(-1,1))
#       3
#       4 plt.plot(X, y, '.')
#       5 plt.plot(X, lin_reg.predict(y.reshape(-1,1)))
#
# ~\Anaconda3\envs\machine_learning\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     682         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     683
# --> 684         X, y = self._validate_data(
#     685             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     686         )
#
# ~\Anaconda3\envs\machine_learning\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     594                 y = check_array(y, input_name="y", **check_y_params)
# ...

# %%
decision_tree4 = DecisionTreeRegressor(max_depth=4)
decision_tree4.fit()
