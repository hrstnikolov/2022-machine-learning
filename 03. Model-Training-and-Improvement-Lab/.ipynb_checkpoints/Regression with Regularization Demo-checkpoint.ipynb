# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression, Lasso, Ridge, RidgeCV, ElasticNet

# %%
RANDOM_STATE = 1

# %% [markdown]
# # Linear Regression with Regularization Demo

# %% [markdown]
# ## Generated data

# %% [markdown]
# ### Single feature

# %%
x, y = make_regression(
    n_samples=100,
    n_features=1,
    noise = 40,
    random_state=RANDOM_STATE,
)

plt.scatter(x, y)
plt.show()

# %%
lr = LinearRegression()
lr_l1 = Lasso(alpha=1)
lr_l2 = Ridge(alpha=1)
lr_both = ElasticNet(alpha = 1.0, l1_ratio = 0.5)
models = [lr, lr_l1, lr_l2, lr_both]

for model in models:
    model.fit(x, y)
    
descriptions = [
    "No regularization",
    "L1",
    "L2",
    "L1 and L2",
]

names = [
    "LinearRegression",
    "Lasso",
    "Ridge",
    "ElasticNet",
]

# %%
for model, name, description in zip(models, names, descriptions):
    R_sq = model.score(x, y)
    print(f"{name} R_sq = {R_sq:.2f}")
# Out:
# LinearRegression R_sq = 0.81
# Lasso R_sq = 0.81
# Ridge R_sq = 0.81
# ElasticNet R_sq = 0.68

# %% [markdown]
# ### Multiple features

# %%
X, y = make_regression(
    n_samples=100,
    n_features=10,
    noise = 40,
    random_state=RANDOM_STATE,
)

plt.scatter(X[:,0], y)
plt.scatter(X[:,1], y)
plt.scatter(X[:,2], y)
plt.show()

# %%
lr = LinearRegression()
lr_l1 = Lasso(alpha=1)
lr_l2 = Ridge(alpha=1)
lr_both = ElasticNet(alpha = 1.0, l1_ratio = 0.5)
models = [lr, lr_l1, lr_l2, lr_both]

for model in models:
    model.fit(X, y)
    
descriptions = [
    "No regularization",
    "L1",
    "L2",
    "L1 and L2",
]

names = [
    "LinearRegression",
    "Lasso",
    "Ridge",
    "ElasticNet",
]

# %%
for model, name, description in zip(models, names, descriptions):
    R_sq = model.score(X, y)
    print(f"{name} R_sq = {R_sq:.2f}")
# Out:
# LinearRegression R_sq = 0.93
# Lasso R_sq = 0.93
# Ridge R_sq = 0.93
# ElasticNet R_sq = 0.79

# %% [markdown]
# #### Rigde tuning

# %%
n_folds = 5
ridge_cv = RidgeCV(
    alphas=np.logspace(1e-3, 1e3, num=3),
    cv=n_folds,)
ridge_cv.fit(X, y)
ridge_cv.score(X, y)
# Out:
# C:\Users\a1056968\Anaconda3\envs\machine_learning\lib\site-packages\numpy\core\function_base.py:277: RuntimeWarning: overflow encountered in power
#   return _nx.power(base, y)
# C:\Users\a1056968\Anaconda3\envs\machine_learning\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 10 fits failed out of a total of 15.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\a1056968\Anaconda3\envs\machine_learning\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\a1056968\Anaconda3\envs\machine_learning\lib\site-packages\sklearn\linear_model\_ridge.py", line 1130, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\a1056968\Anaconda3\envs\machine_learning\lib\site-packages\sklearn\linear_model\_ridge.py", line 889, in fit
#     self.coef_, self.n_iter_ = _ridge_regression(
#   File "C:\Users\a1056968\Anaconda3\envs\machine_learning\lib\site-packages\sklearn\linear_model\_ridge.py", line 699, in _ridge_regression
#     coef = _solve_cholesky(X, y, alpha)
#   File "C:\Users\a1056968\Anaconda3\envs\machine_learning\lib\site-packages\sklearn\linear_model\_ridge.py", line 212, in _solve_cholesky
#     return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
#   File "C:\Users\a1056968\Anaconda3\envs\machine_learning\lib\site-packages\scipy\linalg\basic.py", line 137, in solve
#     a1 = atleast_2d(_asarray_validated(a, check_finite=check_finite))
#   File "C:\Users\a1056968\Anaconda3\envs\machine_learning\lib\site-packages\scipy\_lib\_util.py", line 293, in _asarray_validated
#     a = toarray(a)
#   File "C:\Users\a1056968\Anaconda3\envs\machine_learning\lib\site-packages\numpy\lib\function_base.py", line 488, in asarray_chkfinite
#     raise ValueError(
# ValueError: array must not contain infs or NaNs
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\a1056968\Anaconda3\envs\machine_learning\lib\site-packages\sklearn\model_selection\_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.89122405        nan        nan]
#   warnings.warn(
# 0.9283537010857316
